# %%
#Importing all the libraries 

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Calling all the CSV files 

oct_23 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2023\10. Oct-23 Full Case Report.csv")
nov_23 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2023\11. Nov-23 Full Case Report.csv")
dec_23 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2023\12. Dec-23 Full Case Report.csv")
jan_24 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2024\1. Jan-24 Full Case Report.csv")

#Shapes
print(oct_23.shape)
print(nov_23.shape)
print(dec_23.shape)
print(jan_24.shape)

#Visaulisation of the data 
oct_23.head()
nov_23.head()
dec_23.head()
jan_24.head()
# Out:
# (14575, 73)
# (11555, 73)
# (19659, 73)
# (12630, 73)
#    Case No Operator Who Received Case Reported Condition  \
# 0    54185                        NaN                NaN
# 1    54187                        NaN                NaN
# 2    54191                        NaN                NaN
# 3    54192                        NaN                NaN
# 4    54193                        NaN                NaN
#
#   Receive Time (Badger)    Forename        Surname Sex                 Dob  \
# 0    01-Jan-24 00:06:18      Daniel          James   M  20-May-98 00:00:00
# 1    01-Jan-24 00:25:13       Mandy          Beale   F  25-May-82 00:00:00
# 2    01-Jan-24 00:39:57     Shakira          Saeed   F  28-Apr-09 00:00:00
# 3    01-Jan-24 00:51:20  Wilhelmina      Frederiks   F  02-Dec-20 00:00:00
# 4    01-Jan-24 00:51:45    Caroline  Hopkins-Grant   F  17-Jul-01 00:00:00
#
#          Age     Ethnicity  ... Case Tag Description Case Tag  \
# ...

# %%
#Printing the number of rows in the table 
#Shapes
print("The number of rows for table A is:", oct_23.shape)
print("The number of rows for table B is:", nov_23.shape)
# Out:
# The number of rows for table A is: (14575, 73)
# The number of rows for table B is: (11555, 73)

# %% [markdown]
# Using Union all/Concat Oct_23 and Nov_23

# %%
#setting the max rows 
pd.set_option('display.max_columns', None)

#Printing the shapes 
print("A:", oct_23.shape)
print("B:", nov_23.shape)
print("C:", dec_23.shape)
print("D:", jan_24.shape)

#Union all/concat 

# Concatenate the two DataFrames vertically (union all)
Full_Case_Report_Data = pd.concat([oct_23, nov_23, dec_23, jan_24], ignore_index=True)

# Printing the number of rows in the combined DataFrame
print("The number of rows for the combined table is:", Full_Case_Report_Data.shape[0])
# Out:
# A: (14575, 73)
# B: (11555, 73)
# C: (19659, 73)
# D: (12630, 73)
# The number of rows for the combined table is: 58419

# %%
#To see the head of the new union 
Full_Case_Report_Data.head()
# Out:
#    Case No Operator Who Received Case  \
# 0    93027                        NaN
# 1    93028                        NaN
# 2    93029                        NaN
# 3    93030                   HUSSAINY
# 4    93032                   HUSSAINY
#
#                                   Reported Condition Receive Time (Badger)  \
# 0                                                NaN    01-Oct-23 00:11:02
# 1                                                NaN    01-Oct-23 00:12:59
# 2                                                NaN    01-Oct-23 00:15:08
# 3  Symptoms: Ref: 0110-585-6324; Site: SOLUTC; Na...    01-Oct-23 00:16:45
# 4  Symptoms: Ref: 0110-355-6991; Site: SOLUTC; Na...    01-Oct-23 00:17:52
#
#        Forename    Surname Sex                 Dob       Age     Ethnicity  \
# 0        Shakir      Afzal   M  27-Mar-86 00:00:00  37 years  Not Recorded
# 1  Harlan-James     Newman   M  13-Dec-22 00:00:00  9 months  Not Recorded
# ...

# %%
Full_Case_Report_Data.tail()
# Out:
#        Case No Operator Who Received Case Reported Condition  \
# 58414    71208                        NaN                NaN
# 58415    71214                        NaN                NaN
# 58416    71217                        NaN                NaN
# 58417    71227                        NaN                NaN
# 58418    71231                        NaN                NaN
#
#       Receive Time (Badger)     Forename   Surname Sex                 Dob  \
# 58414    01-Feb-24 00:09:21          Zoe  Robinson   F  06-Feb-73 00:00:00
# 58415    01-Feb-24 00:40:38       Sandra    Barnes   F  29-Jul-49 00:00:00
# 58416    01-Feb-24 00:53:59      Pauline    Salmon   F  25-Jun-38 00:00:00
# 58417    01-Feb-24 01:59:50         Rose    Downes   F  30-Jun-57 00:00:00
# 58418    01-Feb-24 02:03:33  Christopher     Booth   M  25-Aug-02 00:00:00
#
#             Age     Ethnicity                            Address Line1  \
# 58414  50 years  Not Recorded                      177 Brandwood Road
# ...

# %%
# To specify the path in which I want to save this data
Downloads = 'Full_Case_Report_Data.csv'

# To save the combined data frame as a CSV file
Full_Case_Report_Data.to_csv(Downloads, index=False)  # Set index=False to exclude the index column

#To print if the data has been saved 
print(f"The combined data has been saved as '{Downloads}'")
# Out:
# The combined data has been saved as 'Full_Case_Report_Data.csv'

# %%
Full_Case_Report_Data.columns
# Out:
# Index(['Case No', 'Operator Who Received Case', 'Reported Condition',
#        'Receive Time (Badger)', 'Forename', 'Surname', 'Sex', 'Dob', 'Age',
#        'Ethnicity', 'Address Line1', 'Address Line2', 'Address Line3',
#        'Postcode', 'Home Phone', 'Current Address Line1',
#        'Current Address Line2', 'Current Address Line3', 'Current Postcode',
#        'Return Phone No', 'Clinicians Name', 'Provider Group', 'PG Code',
#        'Call Origin', 'Caller Name', 'Caller Phone', 'Initial Case Type',
#        'Final Case Type', 'Reception Priority', 'Priority After Assessment',
#        'Latest Priority', 'Location Name', 'Comfort Call', 'Booked Date',
#        'PCC Arrival', 'Despatch Time', 'Doctor Arrived',
#        'Initial Case Rec Time', '1st Cons Summary', '1st Cons History',
#        '1st Cons Examination', '1st Cons Diagnosis', '1st Cons Treatment',
#        '1st Cons Began Time', '1st Cons End Time', '1st Cons Clinicians Name',
# ...
