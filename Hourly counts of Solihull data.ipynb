# %%
import pandas as pd
import numpy as np

# %%
Urgent.columns
# Out:
# Index(['Case No', 'Operator Who Received Case', 'Reported Condition',
#        'Receive Time (Badger)', 'Forename', 'Surname', 'Sex', 'Dob', 'Age',
#        'Ethnicity', 'Address Line1', 'Address Line2', 'Address Line3',
#        'Postcode', 'Home Phone', 'Current Address Line1',
#        'Current Address Line2', 'Current Address Line3', 'Current Postcode',
#        'Return Phone No', 'Clinicians Name', 'Provider Group', 'PG Code',
#        'Call Origin', 'Caller Name', 'Caller Phone', 'Initial Case Type',
#        'Final Case Type', 'Reception Priority', 'Priority After Assessment',
#        'Latest Priority', 'Location Name', 'Comfort Call', 'Booked Date',
#        'PCC Arrival', 'Despatch Time', 'Doctor Arrived',
#        'Initial Case Rec Time', '1st Cons Summary', '1st Cons History',
#        '1st Cons Examination', '1st Cons Diagnosis', '1st Cons Treatment',
#        '1st Cons Began Time', '1st Cons End Time', '1st Cons Clinicians Name',
# ...

# %%
Urgent = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\Solihull UTS Counts\SolhullUTSCountsJan2024.csv")

# Convert "Last Cons Begin Date" to datetime with the given formatn
Urgent['Last Cons Begin Date'] = pd.to_datetime(Urgent['Last Cons Begin Date'], format='%d/%m/%Y')

# Extract hour from "Last Cons Begin Time Only" column
Urgent['Hour'] = pd.to_datetime(Urgent['Last Cons Begin Time Only'], format='%H:%M').dt.hour

# Combine date and hour to create a new datetime column
Urgent['Combined Datetime'] = Urgent['Last Cons Begin Date'].dt.strftime('%Y-%m-%d') + ' ' + Urgent['Hour'].astype(str) + ':00:00'

# Count occurrences per hour
#hourly_counts = Urgent['Combined Datetime'].value_counts()

# Group by combined datetime and count occurrences
#hourly_counts = Urgent.groupby('Combined Datetime').size()

# Count occurrences per hour
hourly_counts = Urgent['Combined Datetime'].value_counts()

#print(hourly_counts)
print(hourly_counts.to_string())

# Count occurrences per hour
hourly_counts = Urgent['Combined Datetime'].value_counts()

hourly_counts.shape
# Out:
# Combined Datetime
# 2024-01-11 17:00:00    12
# 2024-01-13 17:00:00    11
# 2024-01-20 17:00:00    11
# 2024-01-22 19:00:00    10
# 2024-01-21 19:00:00    10
# 2024-01-19 17:00:00    10
# 2024-01-24 19:00:00     9
# 2024-01-03 13:00:00     9
# 2024-01-02 17:00:00     9
# 2024-01-10 16:00:00     9
# 2024-01-09 18:00:00     9
# 2024-01-22 15:00:00     9
# 2024-01-27 11:00:00     9
# 2024-01-01 19:00:00     9
# 2024-01-23 16:00:00     9
# 2024-01-29 17:00:00     9
# 2024-01-26 17:00:00     9
# 2024-01-16 19:00:00     9
# 2024-01-12 18:00:00     8
# 2024-01-25 15:00:00     8
# 2024-01-14 11:00:00     8
# 2024-01-25 11:00:00     8
# 2024-01-08 17:00:00     8
# 2024-01-28 10:00:00     8
# 2024-01-04 18:00:00     8
# 2024-01-06 17:00:00     8
# 2024-01-09 11:00:00     8
# 2024-01-08 18:00:00     8
# 2024-01-11 11:00:00     8
# 2024-01-20 9:00:00      8
# 2024-01-08 19:00:00     8
# 2024-01-25 17:00:00     8
# 2024-01-22 17:00:00     8
# 2024-01-17 18:00:00     8
# 2024-01-11 13:00:00     8
# ...

# %%
import pandas as pd
import numpy as np
Urgent = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\January 2024 whole month OOH.csv")
# Out:
# C:\Users\Fredrick.Alli\AppData\Local\Temp\ipykernel_4176\2870256053.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 Urgent = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\January 2024 whole month OOH.csv")
#
# ...
