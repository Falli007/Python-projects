# %%
#Importing all the libraries 

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Calling all the CSV files 

oct_23 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2023\Badger consultations October 23.csv")
nov_23 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2023\Badger consultations Nov 23.csv")
dec_23 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2023\Badger consultations Dec 23.csv")
jan_24 = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\2024\Badger consultations Jan-24.csv")

#Shapes
print(oct_23.shape)
print(nov_23.shape)
print(dec_23.shape)
print(jan_24.shape)

#Visaulisation of the data 
oct_23.head()
nov_23.head()
dec_23.head()
jan_24.head()
# Out:
# (9564, 16)
# (9560, 16)
# (14015, 16)
# (9560, 16)
#                                      id   consultation_id             status  \
# 0  7ae7d84d-60b8-4ca3-bcf8-04e3eff27956  170-138-796-7567  COULD_NOT_CONNECT
# 1  5a8a9e66-c068-4c88-aba8-4bf5664185ee  170-138-764-4864          COMPLETED
# 2  60d64341-6c31-44c8-8cb7-0409218f3597  170-138-760-6259          COMPLETED
# 3  8de265a2-64dc-4da1-a4fb-818805d2c3d3  170-138-752-5147          COMPLETED
# 4  6c73918e-3cd6-43d7-b958-b984a35f57a0  170-138-738-7184          COMPLETED
#
#   patient_last_name patient_first_name            date_of_birth  \
# 0             Hanif           Mohammed  1954-11-10 00:00:00.000
# 1            Muneer             Rizwan  2020-03-17 00:00:00.000
# 2           Downing              Julie  1967-12-29 00:00:00.000
# 3          Phillips              Emily  2009-03-31 00:00:00.000
# 4             Carew              Linda  1968-12-20 00:00:00.000
#
# ...

# %%
#Printing the number of rows in the table 
#Shapes
print("The number of rows for table A is:", oct_23.shape)
print("The number of rows for table B is:", nov_23.shape)
# Out:
# The number of rows for table A is: (9564, 16)
# The number of rows for table B is: (9560, 16)

# %% [markdown]
# Using Union all/Concat Oct_23 and Nov_23

# %%
#setting the max rows 
pd.set_option('display.max_columns', None)

#Printing the shapes 
print("A:", oct_23.shape)
print("B:", nov_23.shape)
print("C:", dec_23.shape)
print("D:", jan_24.shape)

#Union all/concat 

# Concatenate the two DataFrames vertically (union all)
Ummanu_Quarterly_Data = pd.concat([oct_23, nov_23, dec_23, jan_24], ignore_index=True)

# Printing the number of rows in the combined DataFrame
print("The number of rows for the combined table is:", Ummanu_Quarterly_Data.shape[0])
# Out:
# A: (9564, 16)
# B: (9560, 16)
# C: (14015, 16)
# D: (9560, 16)
# The number of rows for the combined table is: 42699

# %%
Ummanu_Quarterly_Data.head()
# Out:
#                                      id   consultation_id     status  \
# 0  e7d32bb0-9d93-4ab5-b2f7-840ae4d77aac  169-879-651-6960  COMPLETED
# 1  1832da99-675d-40de-ad00-0e067f5e54f5  169-879-615-4386  COMPLETED
# 2  5d5113df-ea70-4998-8fad-8792aa5d47db  169-879-597-0238  COMPLETED
# 3  09a15d76-348a-4372-94a5-a165e89e4d60  169-879-584-4023  COMPLETED
# 4  00aeab67-e46d-4c49-8cd3-fb6e99d74775  169-879-567-0836  COMPLETED
#
#   patient_last_name patient_first_name            date_of_birth  \
# 0             Moore            Cadence  2006-08-03 00:00:00.000
# 1             Blyth            Jessica  2005-01-16 00:00:00.000
# 2           Alhazmi               Dhai  2016-03-16 00:00:00.000
# 3            Wilson        Abdulrazzaq  2016-01-31 00:00:00.000
# 4              Fiaz            Aaminah  2023-03-03 00:00:00.000
#
#                                              address  priority      key  \
# 0          99 GREENFINCH ROAD, BIRMINGHAM, , B36 0QX         1   URGENT
# ...

# %%
Ummanu_Quarterly_Data.columns
# Out:
# Index(['id', 'consultation_id', 'status', 'patient_last_name',
#        'patient_first_name', 'date_of_birth', 'address', 'priority', 'key',
#        'created_at', 'first_call_attempt_timestamp',
#        'duration_from_creation_to_1st_call', 'conversation_started_timestamp',
#        'duration_from_creation_to_1st_conversation_w_clinician',
#        'reopened_timestamp', 'completed_timestamp'],
#       dtype='object')

# %% [markdown]
# To combine the unique keys

# %%
# To specify the path in which I want to save this data
Downloads = 'Ummanu_Quarterly_Data.csv'

# To save the combined data frame as a CSV file
Ummanu_Quarterly_Data.to_csv(Downloads, index=False)  # Set index=False to exclude the index column

#To print if the data has been saved 
print(f"The combined data has been saved as '{Downloads}'")

# %%
Ummanu_Quarterly_Data.dtypes
# Out:
# id                                                        object
# consultation_id                                           object
# status                                                    object
# patient_last_name                                         object
# patient_first_name                                        object
# date_of_birth                                             object
# address                                                   object
# priority                                                   int64
# key                                                       object
# created_at                                                object
# first_call_attempt_timestamp                              object
# duration_from_creation_to_1st_call                        object
# conversation_started_timestamp                            object
# duration_from_creation_to_1st_conversation_w_clinician    object
# ...

# %%
Ummanu_Quarterly_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42699 entries, 0 to 42698
# Data columns (total 16 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   id                                                      42699 non-null  object
#  1   consultation_id                                         42699 non-null  object
#  2   status                                                  42699 non-null  object
#  3   patient_last_name                                       42699 non-null  object
#  4   patient_first_name                                      42699 non-null  object
#  5   date_of_birth                                           42699 non-null  object
#  6   address                                                 40345 non-null  object
#  7   priority                                                42699 non-null  int64
# ...

# %% [markdown]
# To call the Umanu quarterly report data

# %%
Ummanu_Quarterly_Data = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\Ummanu_Quarterly_Data.csv")

# %%
Ummanu_Quarterly_Data.head()
# Out:
#                                      id   consultation_id     status  \
# 0  e7d32bb0-9d93-4ab5-b2f7-840ae4d77aac  169-879-651-6960  COMPLETED
# 1  1832da99-675d-40de-ad00-0e067f5e54f5  169-879-615-4386  COMPLETED
# 2  5d5113df-ea70-4998-8fad-8792aa5d47db  169-879-597-0238  COMPLETED
# 3  09a15d76-348a-4372-94a5-a165e89e4d60  169-879-584-4023  COMPLETED
# 4  00aeab67-e46d-4c49-8cd3-fb6e99d74775  169-879-567-0836  COMPLETED
#
#   patient_last_name patient_first_name date_of_birth  \
# 0             Moore            Cadence    03/08/2006
# 1             Blyth            Jessica    16/01/2005
# 2           Alhazmi               Dhai    16/03/2016
# 3            Wilson        Abdulrazzaq    31/01/2016
# 4              Fiaz            Aaminah    03/03/2023
#
#                                              address  priority      key  \
# 0          99 GREENFINCH ROAD, BIRMINGHAM, , B36 0QX         1   URGENT
# 1  541 PETERBROOK ROAD, SHIRLEY, SOLIHULL, , B90 1HS         0  ROUTINE
# ...

# %%
Ummanu_Quarterly_Data.dtypes
# Out:
# id                                                        object
# consultation_id                                           object
# status                                                    object
# patient_last_name                                         object
# patient_first_name                                        object
# date_of_birth                                             object
# address                                                   object
# priority                                                   int64
# key                                                       object
# created_at                                                object
# first_call_attempt_timestamp                              object
# duration_from_creation_to_1st_call                        object
# conversation_started_timestamp                            object
# duration_from_creation_to_1st_conversation_w_clinician    object
# ...

# %%
Ummanu_Quarterly_Data.head()

# Combine columns to create 'unique_ID'
Ummanu_Quarterly_Data['unique_ID'] = Ummanu_Quarterly_Data['patient_last_name'] + ' ' + \
                                     Ummanu_Quarterly_Data['patient_first_name'] + ' ' + \
                                     Ummanu_Quarterly_Data['date_of_birth'] + ' DOB ' + \
                                     Ummanu_Quarterly_Data['created_at'] + ' Day '

print(Ummanu_Quarterly_Data)
# Out:
#                                          id   consultation_id  \
# 0      e7d32bb0-9d93-4ab5-b2f7-840ae4d77aac  169-879-651-6960
# 1      1832da99-675d-40de-ad00-0e067f5e54f5  169-879-615-4386
# 2      5d5113df-ea70-4998-8fad-8792aa5d47db  169-879-597-0238
# 3      09a15d76-348a-4372-94a5-a165e89e4d60  169-879-584-4023
# 4      00aeab67-e46d-4c49-8cd3-fb6e99d74775  169-879-567-0836
# ...                                     ...               ...
# 42694  5e794180-5bc1-442b-8bdb-b871d292c73a  169-879-757-7634
# 42695  41d70171-b272-4c83-8783-532d95f74a69  169-879-733-4121
# 42696  673d6cf2-e338-4730-870f-baa3c5c95835  169-879-722-9307
# 42697  12fede3f-5f0e-4741-a55e-290676be0921  169-879-716-2699
# 42698  01ea084d-6271-4100-9acf-df9d474eeac8  169-879-711-3777
#
#                   status patient_last_name patient_first_name date_of_birth  \
# 0              COMPLETED             Moore            Cadence    03/08/2006
# ...

# %%
Ummanu_Quarterly_Data.head()
# Out:
#                                      id   consultation_id     status  \
# 0  e7d32bb0-9d93-4ab5-b2f7-840ae4d77aac  169-879-651-6960  COMPLETED
# 1  1832da99-675d-40de-ad00-0e067f5e54f5  169-879-615-4386  COMPLETED
# 2  5d5113df-ea70-4998-8fad-8792aa5d47db  169-879-597-0238  COMPLETED
# 3  09a15d76-348a-4372-94a5-a165e89e4d60  169-879-584-4023  COMPLETED
# 4  00aeab67-e46d-4c49-8cd3-fb6e99d74775  169-879-567-0836  COMPLETED
#
#   patient_last_name patient_first_name date_of_birth  \
# 0             Moore            Cadence    03/08/2006
# 1             Blyth            Jessica    16/01/2005
# 2           Alhazmi               Dhai    16/03/2016
# 3            Wilson        Abdulrazzaq    31/01/2016
# 4              Fiaz            Aaminah    03/03/2023
#
#                                              address  priority      key  \
# 0          99 GREENFINCH ROAD, BIRMINGHAM, , B36 0QX         1   URGENT
# 1  541 PETERBROOK ROAD, SHIRLEY, SOLIHULL, , B90 1HS         0  ROUTINE
# ...

# %%
Ummanu_Quarterly_Data.columns
# Out:
# Index(['id', 'consultation_id', 'status', 'patient_last_name',
#        'patient_first_name', 'date_of_birth', 'address', 'priority', 'key',
#        'created_at', 'first_call_attempt_timestamp',
#        'duration_from_creation_to_1st_call', 'conversation_started_timestamp',
#        'duration_from_creation_to_1st_conversation_w_clinician',
#        'reopened_timestamp', 'completed_timestamp', 'unique_ID'],
#       dtype='object')

# %%
#To count the number of cases cancelled
# Replace 'cancelled' with the status you're interested in
cancelled_count = Ummanu_Quarterly_Data[Ummanu_Quarterly_Data['status'] == 'CANCELED']['unique_ID'].nunique()

print("Number of unique IDs with status 'cancelled':", cancelled_count)
# Out:
# Number of unique IDs with status 'cancelled': 5522

# %%
#To count the number of cases cancelled
# Replace 'cancelled' with the status you're interested in
completed_count = Ummanu_Quarterly_Data[Ummanu_Quarterly_Data['status'] == 'COMPLETED']['unique_ID'].nunique()

print("Number of unique IDs with status 'completed':", completed_count)
# Out:
# Number of unique IDs with status 'completed': 24400

# %%
Ummanu_Quarterly_Data.shape
# Out:
# (42699, 17)

# %%
# Replace 'cancelled' with the status you're interested in
cancelled_data = Ummanu_Quarterly_Data[Ummanu_Quarterly_Data['status'] == 'CANCELED'][['unique_ID']]

# Save the filtered data to a new CSV file
cancelled_data.to_csv('cancelled_unique_ids.csv', index=False)

print("Cancelled unique IDs saved to cancelled_unique_ids.csv")
# Out:
# Cancelled unique IDs saved to cancelled_unique_ids.csv

# %%
# To specify the path in which I want to save this data
Downloads = 'cancelled_data.csv'

# To save the combined data frame as a CSV file
cancelled_data.to_csv(Downloads, index=False)  # Set index=False to exclude the index column

#To print if the data has been saved 
print(f"The combined data has been saved as '{Downloads}'")
# Out:
# The combined data has been saved as 'cancelled_data.csv'

# %%
cancelled_data.head()
# Out:
#                                             unique_ID
# 6    Kite Kenneth John 10/06/1946 DOB 31/10/2023 Day
# 8   Wright Tracy Susan 10/08/1962 DOB 31/10/2023 Day
# 27         Laleye Seyi 16/02/1980 DOB 31/10/2023 Day
# 28       Adeel Zaviyar 20/10/2023 DOB 31/10/2023 Day
# 29           Price Zoe 10/03/1988 DOB 31/10/2023 Day

# %%
cancelled_data.shape
# Out:
# (7195, 1)

# %% [markdown]
# Bringing up Adastra Cases

# %%
Adastra_Report = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\Full Case Report Data Oct-Jan.csv")

# %%
Adastra_Report.head()
# Out:
#    Case No Operator Who Received Case  \
# 0    93027                        NaN
# 1    93028                        NaN
# 2    93029                        NaN
# 3    93030                   HUSSAINY
# 4    93032                   HUSSAINY
#
#                                   Reported Condition Receive Time (Badger)  \
# 0                                                NaN            01/10/2023
# 1                                                NaN            01/10/2023
# 2                                                NaN            01/10/2023
# 3  Symptoms: Ref: 0110-585-6324; Site: SOLUTC; Na...            01/10/2023
# 4  Symptoms: Ref: 0110-355-6991; Site: SOLUTC; Na...            01/10/2023
#
#        Forename    Surname Sex         Dob       Age     Ethnicity  \
# 0        Shakir      Afzal   M  27/03/1986  37 years  Not Recorded
# 1  Harlan-James     Newman   M  13/12/2022  9 months  Not Recorded
# 2        Afshah    Mahmood   F  12/04/1994  29 years  Not Recorded
# ...

# %%
Adastra_Report.shape
# Out:
# (58419, 73)

# %%
Adastra_Report.head()

# Combine columns to create 'unique_ID'
Adastra_Report['unique_ID'] = Adastra_Report['Forename'] + ' ' + \
                              Adastra_Report['Surname'] + ' ' + \
                              Adastra_Report['Dob'] + ' DOB ' + \
                              Adastra_Report['Receive Time (Badger)'] + ' Day '

print(Adastra_Report)
# Out:
#        Case No Operator Who Received Case  \
# 0        93027                        NaN
# 1        93028                        NaN
# 2        93029                        NaN
# 3        93030                   HUSSAINY
# 4        93032                   HUSSAINY
# ...        ...                        ...
# 58414    71208                        NaN
# 58415    71214                        NaN
# 58416    71217                        NaN
# 58417    71227                        NaN
# 58418    71231                        NaN
#
#                                       Reported Condition  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Symptoms: Ref: 0110-585-6324; Site: SOLUTC; Na...
# 4      Symptoms: Ref: 0110-355-6991; Site: SOLUTC; Na...
# ...                                                  ...
# ...

# %%
Adastra_Report.head()
# Out:
#    Case No Operator Who Received Case  \
# 0    93027                        NaN
# 1    93028                        NaN
# 2    93029                        NaN
# 3    93030                   HUSSAINY
# 4    93032                   HUSSAINY
#
#                                   Reported Condition Receive Time (Badger)  \
# 0                                                NaN            01/10/2023
# 1                                                NaN            01/10/2023
# 2                                                NaN            01/10/2023
# 3  Symptoms: Ref: 0110-585-6324; Site: SOLUTC; Na...            01/10/2023
# 4  Symptoms: Ref: 0110-355-6991; Site: SOLUTC; Na...            01/10/2023
#
#        Forename    Surname Sex         Dob       Age     Ethnicity  \
# 0        Shakir      Afzal   M  27/03/1986  37 years  Not Recorded
# 1  Harlan-James     Newman   M  13/12/2022  9 months  Not Recorded
# 2        Afshah    Mahmood   F  12/04/1994  29 years  Not Recorded
# ...

# %%
Adastra_Report.columns
# Out:
# Index(['Case No', 'Operator Who Received Case', 'Reported Condition',
#        'Receive Time (Badger)', 'Forename', 'Surname', 'Sex', 'Dob', 'Age',
#        'Ethnicity', 'Address Line1', 'Address Line2', 'Address Line3',
#        'Postcode', 'Home Phone', 'Current Address Line1',
#        'Current Address Line2', 'Current Address Line3', 'Current Postcode',
#        'Return Phone No', 'Clinicians Name', 'Provider Group', 'PG Code',
#        'Call Origin', 'Caller Name', 'Caller Phone', 'Initial Case Type',
#        'Final Case Type', 'Reception Priority', 'Priority After Assessment',
#        'Latest Priority', 'Location Name', 'Comfort Call', 'Booked Date',
#        'PCC Arrival', 'Despatch Time', 'Doctor Arrived',
#        'Initial Case Rec Time', '1st Cons Summary', '1st Cons History',
#        '1st Cons Examination', '1st Cons Diagnosis', '1st Cons Treatment',
#        '1st Cons Began Time', '1st Cons End Time', '1st Cons Clinicians Name',
# ...

# %%
# To specify the path in which I want to save this data
Downloads = 'Adastra_Report.csv'

# To save the combined data frame as a CSV file
Adastra_Report.to_csv(Downloads, index=False)  # Set index=False to exclude the index column

#To print if the data has been saved 
print(f"The combined data has been saved as '{Downloads}'")
# Out:
# The combined data has been saved as 'Adastra_Report.csv'

# %% [markdown]
# To find the match between Ummanu and Adastra

# %%
# Merge the cancelled_data DataFrame with adastra_report based on the 'unique_ID' column
merged_data = pd.merge(cancelled_data, Adastra_Report, on='unique_ID', how='inner')
merged_data.head()
# Out:
#                                         unique_ID  Case No  \
# 0   Gilbert Davies 31/12/1936 DOB 19/10/2023 Day     11644
# 1     Fayaz Misbah 02/06/1992 DOB 17/10/2023 Day     11116
# 2  Akhlaq Mohammed 25/02/1970 DOB 06/10/2023 Day     95461
# 3  Akhlaq Mohammed 25/02/1970 DOB 06/10/2023 Day     95461
# 4  Akhlaq Mohammed 25/02/1970 DOB 05/10/2023 Day     95142
#
#   Operator Who Received Case Reported Condition Receive Time (Badger)  \
# 0                        NaN                NaN            19/10/2023
# 1                        NaN                NaN            17/10/2023
# 2                        NaN                NaN            06/10/2023
# 3                        NaN                NaN            06/10/2023
# 4                        NaN                NaN            05/10/2023
#
#   Forename   Surname Sex         Dob       Age     Ethnicity  \
# 0  Gilbert    Davies   M  31/12/1936  86 years  Not Recorded
# 1    Fayaz    Misbah   F  02/06/1992  31 years  Not Recorded
# ...

# %%
# Merge the cancelled_data DataFrame with adastra_report based on the 'unique_ID' column
merged_data = pd.merge(cancelled_data, Adastra_Report, on='unique_ID', how='inner')
merged_data.head()

# Save the merged data to a new CSV file
#merged_data.to_csv('matched_adastra_report.csv', index=False)

#print("Matched data from Adastra_Report saved to matched_adastra_report.csv")
# Out:
#                                         unique_ID  Case No  \
# 0   Gilbert Davies 31/12/1936 DOB 19/10/2023 Day     11644
# 1     Fayaz Misbah 02/06/1992 DOB 17/10/2023 Day     11116
# 2  Akhlaq Mohammed 25/02/1970 DOB 06/10/2023 Day     95461
# 3  Akhlaq Mohammed 25/02/1970 DOB 06/10/2023 Day     95461
# 4  Akhlaq Mohammed 25/02/1970 DOB 05/10/2023 Day     95142
#
#   Operator Who Received Case Reported Condition Receive Time (Badger)  \
# 0                        NaN                NaN            19/10/2023
# 1                        NaN                NaN            17/10/2023
# 2                        NaN                NaN            06/10/2023
# 3                        NaN                NaN            06/10/2023
# 4                        NaN                NaN            05/10/2023
#
#   Forename   Surname Sex         Dob       Age     Ethnicity  \
# 0  Gilbert    Davies   M  31/12/1936  86 years  Not Recorded
# 1    Fayaz    Misbah   F  02/06/1992  31 years  Not Recorded
# ...

# %%
merged_data.head()
# Out:
#                                         unique_ID  Case No  \
# 0   Gilbert Davies 31/12/1936 DOB 19/10/2023 Day     11644
# 1     Fayaz Misbah 02/06/1992 DOB 17/10/2023 Day     11116
# 2  Akhlaq Mohammed 25/02/1970 DOB 06/10/2023 Day     95461
# 3  Akhlaq Mohammed 25/02/1970 DOB 06/10/2023 Day     95461
# 4  Akhlaq Mohammed 25/02/1970 DOB 05/10/2023 Day     95142
#
#   Operator Who Received Case Reported Condition Receive Time (Badger)  \
# 0                        NaN                NaN            19/10/2023
# 1                        NaN                NaN            17/10/2023
# 2                        NaN                NaN            06/10/2023
# 3                        NaN                NaN            06/10/2023
# 4                        NaN                NaN            05/10/2023
#
#   Forename   Surname Sex         Dob       Age     Ethnicity  \
# 0  Gilbert    Davies   M  31/12/1936  86 years  Not Recorded
# 1    Fayaz    Misbah   F  02/06/1992  31 years  Not Recorded
# ...

# %%
merged_data.shape
# Out:
# (11, 74)

# %%
merged_data.tail()
# Out:
#                                          unique_ID  Case No  \
# 6   Muhammad Hassan 13/08/2008 DOB 04/10/2023 Day     94687
# 7     Arushi Arushi 22/02/1998 DOB 30/12/2023 Day     52381
# 8     Hassan Hassan 01/01/1941 DOB 29/12/2023 Day     51706
# 9   Anjeena Anjeena 20/07/1996 DOB 06/12/2023 Day     36912
# 10      Nancy Nancy 05/12/1996 DOB 02/12/2023 Day     34400
#
#    Operator Who Received Case  \
# 6                    BEGUMZAN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
#
#                                    Reported Condition Receive Time (Badger)  \
# 6   Symptoms: Ref: 0410-609-6046; Site: ESGUTC; Na...            04/10/2023
# 7                                                 NaN            30/12/2023
# 8                                                 NaN            29/12/2023
# 9                                                 NaN            06/12/2023
# ...

# %% [markdown]
# To merge cancelled data and adastra

# %%
ummanu = pd.read_csv(r"C:\Users\Fredrick.Alli\Documents\Ummanu_Cancelled.csv")
adastra  = pd.read_csv(r"C:\Users\Fredrick.Alli\PycharmProjects\CombiningCSVfiles\Adastra_Report.csv")

ummanu.head()

# Merge the cancelled_data DataFrame with adastra_report based on the 'unique_ID' column
#merged_data = pd.merge(Ummanu, Adastra_Report, on='unique_ID', how='inner')
#merged_data.head()

# Save the merged data to a new CSV file
#merged_data.to_csv('matched_adastra_report.csv', index=False)

#print("Matched data from Adastra_Report saved to matched_adastra_report.csv")
# Out:
#                                      id   consultation_id    status Lastname  \
# 0  74812c06-a97c-43fd-ae40-8e638b89b212  169-959-520-5680  CANCELED  Aakifah
# 1  74812c06-a97c-43fd-ae40-8e638b89b212  169-959-520-5680  CANCELED  Aakifah
# 2  4b0b971f-b69e-44f1-80ce-ff0a6a6894f8  170-206-597-7970  CANCELED   Abbasi
# 3  cc9c7f6a-55e4-4b4a-a552-ab9330271413  169-726-571-1354  CANCELED    Abbas
# 4  d3a8c58e-0b62-4dfa-ad75-c306a760e126  169-826-835-3202  CANCELED    Abbas
#
#   Firstname         Dob                                            address  \
# 0    Alayna  17/03/2023            39 SOLIHULL LANE, BIRMINGHAM, , B28 9LS
# 1    Alayna  17/03/2023            39 SOLIHULL LANE, BIRMINGHAM, , B28 9LS
# 2   Safoora  08/03/1991  110 Preston Road, Yardley, Birmingham, West Mi...
# 3    Zameer  09/12/1981              43 TRINITY ROAD, BIRMINGHAM, , B6 6AJ
# 4      Zoya  11/04/2022           52A, CALDWELL ROAD, BIRMINGHAM, , B9 5TH
#
# ...

# %%
adastra.head()
# Out:
#    Case No Operator Who Received Case Reported Condition  \
# 0    61682                        NaN                NaN
# 1    93541                        NaN                NaN
# 2    48363                        NaN                NaN
# 3    50174                        NaN                NaN
# 4    51373                        NaN                NaN
#
#   Receive Time (Badger) Fistname Lastname Sex         Dob       Age  \
# 0            14/01/2024    Aadam    Ahmed   M  19/11/2013  10 years
# 1            01/10/2023    Aadam    Akram   M  18/02/2015   8 years
# 2            24/12/2023    Aadam   Hassan   M  04/05/2012  11 years
# 3            26/12/2023    Aadam   Hassan   M  04/05/2012  11 years
# 4            29/12/2023    Aadam   Hassan   M  04/05/2012  11 years
#
#                           Ethnicity            Address Line1 Address Line2  \
# 0                      Not Recorded         1 Parktree Walk      Erdington
# ...

# %%
ummanu.head()
# Out:
#                                      id   consultation_id    status Lastname  \
# 0  74812c06-a97c-43fd-ae40-8e638b89b212  169-959-520-5680  CANCELED  Aakifah
# 1  74812c06-a97c-43fd-ae40-8e638b89b212  169-959-520-5680  CANCELED  Aakifah
# 2  4b0b971f-b69e-44f1-80ce-ff0a6a6894f8  170-206-597-7970  CANCELED   Abbasi
# 3  cc9c7f6a-55e4-4b4a-a552-ab9330271413  169-726-571-1354  CANCELED    Abbas
# 4  d3a8c58e-0b62-4dfa-ad75-c306a760e126  169-826-835-3202  CANCELED    Abbas
#
#   Firstname         Dob                                            address  \
# 0    Alayna  17/03/2023            39 SOLIHULL LANE, BIRMINGHAM, , B28 9LS
# 1    Alayna  17/03/2023            39 SOLIHULL LANE, BIRMINGHAM, , B28 9LS
# 2   Safoora  08/03/1991  110 Preston Road, Yardley, Birmingham, West Mi...
# 3    Zameer  09/12/1981              43 TRINITY ROAD, BIRMINGHAM, , B6 6AJ
# 4      Zoya  11/04/2022           52A, CALDWELL ROAD, BIRMINGHAM, , B9 5TH
#
# ...

# %%
ummanu.columns
# Out:
# Index(['id', 'consultation_id', 'status', 'Lastname', 'Firstname', 'Dob',
#        'address', 'priority', 'key', 'Received Time',
#        'first_call_attempt_timestamp', 'duration_from_creation_to_1st_call',
#        'conversation_started_timestamp',
#        'duration_from_creation_to_1st_conversation_w_clinician',
#        'reopened_timestamp', 'completed_timestamp', 'UniqueID'],
#       dtype='object')

# %%
#Merge the cancelled_data DataFrame with adastra_report based on the 'unique_ID' column
merged_data = pd.merge(ummanu, adastra, on='UniqueID', how='inner')
merged_data.head()
# Out:
#                                      id   consultation_id    status  \
# 0  314e035a-b940-4411-8308-02bef987c5aa  169-654-182-3663  CANCELED
# 1  c87363ce-f411-4838-bd39-ed10a9af36cb  169-663-607-9201  CANCELED
# 2  a4e5d35c-de8a-4fa0-8035-d3474225dc75  169-662-046-7250  CANCELED
# 3  a1ef9f20-9d7e-4ad5-899f-3e52d73ce765  170-189-642-0063  CANCELED
# 4  2c0fb667-4401-4670-ab9c-bf645e203910  170-393-851-1475  CANCELED
#
#   Lastname_x Firstname       Dob_x  \
# 0     Akhlaq  Mohammed  25/02/1970
# 1     Akhlaq  Mohammed  25/02/1970
# 2     Akhlaq  Mohammed  25/02/1970
# 3    Anjeena   Anjeena  20/07/1996
# 4     Arushi    Arushi  22/02/1998
#
#                                              address  priority      key  \
# 0  111 THIRD AVENUE, BORDESLEY GREEN, BIRMINGHAM,...         0  ROUTINE
# 1  111 THIRD AVENUE, BORDESLEY GREEN, BIRMINGHAM,...         0  ROUTINE
# 2  111 THIRD AVENUE, BORDESLEY GREEN, BIRMINGHAM,...         0  ROUTINE
# ...

# %%
merged_data.head(12)
# Out:
#                                       id   consultation_id    status  \
# 0   314e035a-b940-4411-8308-02bef987c5aa  169-654-182-3663  CANCELED
# 1   c87363ce-f411-4838-bd39-ed10a9af36cb  169-663-607-9201  CANCELED
# 2   a4e5d35c-de8a-4fa0-8035-d3474225dc75  169-662-046-7250  CANCELED
# 3   a1ef9f20-9d7e-4ad5-899f-3e52d73ce765  170-189-642-0063  CANCELED
# 4   2c0fb667-4401-4670-ab9c-bf645e203910  170-393-851-1475  CANCELED
# 5   ce2fbba7-e2d7-4e0f-9c3c-caf85db878c3  169-756-825-5770  CANCELED
# 6   464dafdc-cce6-4b4a-a3f9-713b61e33829  169-767-820-7585  CANCELED
# 7   63213ec9-3da4-45e3-8b51-1dc98917c0c5  170-387-529-8875  CANCELED
# 8   84bcb15a-0f20-4ef9-ba16-75fd5eabdcdd  169-644-328-6139  CANCELED
# 9   84bcb15a-0f20-4ef9-ba16-75fd5eabdcdd  169-644-328-6139  CANCELED
# 10  e10297c8-acce-4bd1-a4fa-71808799b376  170-152-182-6036  CANCELED
#
#    Lastname_x Firstname       Dob_x  \
# 0      Akhlaq  Mohammed  25/02/1970
# 1      Akhlaq  Mohammed  25/02/1970
# ...
